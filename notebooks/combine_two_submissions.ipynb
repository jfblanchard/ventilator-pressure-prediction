# %% [markdown]
# Look at two different submissions to troublshoot or engineer.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sub1 = pd.read_csv(r'C:\Sync\Work\Kaggle Competitions\Ventilator Pressure Prediction\Notebooks\submission.csv')
sub2 = pd.read_csv(r'C:\Sync\Work\Kaggle Competitions\Ventilator Pressure Prediction\Notebooks\submission_rf_.55.csv')

# %%
deltas = sub1[0:35] - sub2[0:35]

# %%
sub1[0:35].plot()
sub2[0:35].plot()
# Out:
# <AxesSubplot:>

# %%
deltas.plot()
plt.title(f'Residuals')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-44dd3d7a29e6> in <module>
# ----> 1 deltas.plot()
#       2 plt.title(f'Residuals')
#
# NameError: name 'deltas' is not defined

# %%
sub_mean = sub1.copy()
sub_mean.pressure = (sub1.pressure + sub2.pressure)/2

# %%
sub_mean.to_csv('submission.csv', index=False)
print("Submission saved!")
# Out:
# Submission saved!

# %%
sub_mean
# Out:
#               id  pressure
# 0              1  6.439994
# 1              2  6.067029
# 2              3  7.347152
# 3              4  7.774405
# 4              5  9.303883
# ...          ...       ...
# 4023995  4023996  1.000000
# 4023996  4023997  1.000000
# 4023997  4023998  1.000000
# 4023998  4023999  1.000000
# 4023999  4024000  1.000000
#
# [4024000 rows x 2 columns]

# %%
sub1.head(35)
# Out:
#     id   pressure
# 0    1   6.473751
# 1    2   6.120109
# 2    3   7.403666
# 3    4   7.734422
# 4    5   9.404910
# 5    6  10.778561
# 6    7  12.031306
# 7    8  13.044207
# 8    9  14.681351
# 9   10  15.090831
# 10  11  17.022136
# 11  12  17.911916
# 12  13  18.327735
# 13  14  18.861578
# 14  15  19.895126
# 15  16  20.263208
# 16  17  21.287376
# 17  18  22.630063
# 18  19  21.864322
# 19  20  22.513064
# 20  21  22.852000
# 21  22  23.822693
# 22  23  23.976289
# 23  24  24.259743
# 24  25  24.665871
# 25  26  24.620620
# 26  27  24.532289
# 27  28  25.135136
# 28  29  24.552184
# 29  30  24.739960
# 30  31  24.324988
# 31  32   1.000000
# 32  33   1.000000
# 33  34   1.000000
# 34  35   1.000000

# %%
sub2.head(35)
# Out:
#     id   pressure
# 0    1   5.835383
# 1    2   5.948569
# 2    3   6.496926
# 3    4   7.085355
# 4    5   8.618645
# 5    6   9.784254
# 6    7  11.122807
# 7    8  11.948857
# 8    9  13.056116
# 9   10  14.373578
# 10  11  15.364838
# 11  12  15.802118
# 12  13  16.845402
# 13  14  17.875328
# 14  15  18.713330
# 15  16  19.166778
# 16  17  19.909169
# 17  18  20.388630
# 18  19  21.250534
# 19  20  21.885362
# 20  21  22.385914
# 21  22  22.965906
# 22  23  22.942004
# 23  24  23.271018
# 24  25  23.702673
# 25  26  23.697752
# 26  27  23.430604
# 27  28  23.026366
# 28  29  22.393647
# 29  30  22.340920
# 30  31  22.347248
# 31  32   1.000000
# 32  33   1.000000
# 33  34   1.000000
# 34  35   1.000000
